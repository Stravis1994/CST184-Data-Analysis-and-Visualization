# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create an undirected graph
G = nx.Graph()

# Add nodes
G.add_nodes_from([
    "Village School", "Learning Hub", "EdTech Van", 
    "City School", "Remote School", "Library"
])

# Add edges (connections between nodes)
G.add_edges_from([
    ("Village School", "Learning Hub"),
    ("Learning Hub", "EdTech Van"),
    ("City School", "Library"),
    ("EdTech Van", "Remote School"),
    ("Library", "Remote School")
])

# Draw the graph
plt.figure(figsize=(8,6))
nx.draw(G, with_labels=True, node_color="skyblue", node_size=1500, font_size=10)
plt.title("Education Network – SDG 4: Quality Education")
plt.show()

# %%
# Number of nodes and edges
print("Nodes:", G.number_of_nodes())
print("Edges:", G.number_of_edges())

# Degree of each node (number of connections)
for node in G.nodes():
    print(f"{node} has degree {G.degree(node)}")

# Check connectivity
print("Is the graph connected?", nx.is_connected(G))
# Out:
# Nodes: 6
# Edges: 5
# Village School has degree 1
# Learning Hub has degree 2
# EdTech Van has degree 2
# City School has degree 1
# Remote School has degree 2
# Library has degree 2
# Is the graph connected? True

# %%
G.add_node("New Mobile Unit")
G.add_edge("New Mobile Unit", "Village School")

#Remove a connection:

G.remove_edge("Library", "Remote School")

#Try Re-plotting the Graph:

nx.draw(G, with_labels=True, node_color="lightgreen", node_size=1500)
plt.title("Modified Network")
plt.show()

# %%
G_weighted = nx.Graph()
G_weighted.add_weighted_edges_from([
    ("Village School", "Learning Hub", 5),
    ("Learning Hub", "EdTech Van", 3),
    ("City School", "Library", 2),
    ("EdTech Van", "Remote School", 12),
    ("Library", "Remote School", 10)
])

# Draw with edge weights
pos = nx.spring_layout(G_weighted)
nx.draw(G_weighted, pos, with_labels=True, node_color="lightblue", node_size=1500)
edge_labels = nx.get_edge_attributes(G_weighted, 'weight')
nx.draw_networkx_edge_labels(G_weighted, pos, edge_labels=edge_labels)
plt.title("Weighted Education Network")
plt.show()
