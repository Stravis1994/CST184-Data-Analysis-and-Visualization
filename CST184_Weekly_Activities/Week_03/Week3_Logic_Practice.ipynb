# %%
# Scenario:
# You are assessing whether a country qualifies for Policy A.
# Policy A is designed to reward countries with high renewable energy use
# and low CO₂ emissions per capita.

# Country data (you can modify these values below)
country_name = "Nepal"
percent_renewable = 60
co2_emissions = 1.8
region = "Asia"

# Define logical conditions
is_high_renewable = percent_renewable > 50
is_low_emission = co2_emissions < 2

# Combined logical proposition using AND
if is_high_renewable and is_low_emission:
    print(f"{country_name} qualifies for Policy A")
else:
    print(f"{country_name} does not qualify for Policy A")

# Display Boolean values for learning
print("High Renewable:", is_high_renewable)
print("Low Emission:", is_low_emission)
# Out:
# Nepal qualifies for Policy A
# High Renewable: True
# Low Emission: True

# %%
# Changing percent_renewable to 45% to see the effect on qualification

# Country data (you can modify these values below)
country_name = "Nepal"
percent_renewable = 45
co2_emissions = 1.8
region = "Asia"

# Define logical conditions
is_high_renewable = percent_renewable > 50
is_low_emission = co2_emissions < 2

# Combined logical proposition using AND
if is_high_renewable and is_low_emission:
    print(f"{country_name} qualifies for Policy A")
else:
    print(f"{country_name} does not qualify for Policy A")

# Display Boolean values for learning
print("High Renewable:", is_high_renewable)
print("Low Emission:", is_low_emission)
# Out:
# Nepal does not qualify for Policy A
# High Renewable: False
# Low Emission: True

# %%
# Access data from the CSV file and apply the logic to all the countries in the dataset
import pandas as pd


df= pd.read_csv("week3_policy_data.csv")

# Country data (you can modify these values below)
for index, row in df.iterrows():
    country_name = row['Country'] # Get the first country name
    percent_renewable = row['%Renewable']  # Get the first percent_renewable value
    co2_emissions = row['CO2_per_capita']  # Get the first CO2_per_capita value
    region = row['Region']  # Get the first region value


# Define logical conditions
    is_high_renewable = percent_renewable > 50
    is_low_emission = co2_emissions < 2
    region = region

# Combined logical proposition using AND
    if is_high_renewable and is_low_emission:
        print(f"{country_name} qualifies for Policy A")
    else:
        print(f"{country_name} does not qualify for Policy A")

    # Display Boolean values for learning
    print("High Renewable:", is_high_renewable)
    print("Low Emission:", is_low_emission)
# Out:
# Nepal qualifies for Policy A
# High Renewable: True
# Low Emission: True
# Kenya qualifies for Policy A
# High Renewable: True
# Low Emission: True
# Germany does not qualify for Policy A
# High Renewable: False
# Low Emission: False
# India does not qualify for Policy A
# High Renewable: False
# Low Emission: True
# Australia does not qualify for Policy A
# High Renewable: False
# Low Emission: False
# Brazil does not qualify for Policy A
# High Renewable: True
# Low Emission: False
# Nigeria does not qualify for Policy A
# High Renewable: False
# Low Emission: True
# Sweden does not qualify for Policy A
# High Renewable: True
# Low Emission: False
# Bangladesh does not qualify for Policy A
# High Renewable: False
# Low Emission: True
# USA does not qualify for Policy A
# High Renewable: False
# Low Emission: False

# %%
# Change the logic to allow countries with high renewable OR low emissions to qualify.

import pandas as pd


df= pd.read_csv("week3_policy_data.csv")

# Country data (you can modify these values below)
for index, row in df.iterrows():
    country_name = row['Country'] # Get the first country name
    percent_renewable = row['%Renewable']  # Get the first percent_renewable value
    co2_emissions = row['CO2_per_capita']  # Get the first CO2_per_capita value
    region = row['Region']  # Get the first region value


# Define logical conditions
    is_high_renewable = percent_renewable > 50
    is_low_emission = co2_emissions < 2
    region = region

# Combined logical proposition using AND
    if is_high_renewable or is_low_emission:
        print(f"{country_name} qualifies for Policy A")
    else:
        print(f"{country_name} does not qualify for Policy A")

    # Display Boolean values for learning
    print("High Renewable:", is_high_renewable)
    print("Low Emission:", is_low_emission)
# Out:
# Nepal qualifies for Policy A
# High Renewable: True
# Low Emission: True
# Kenya qualifies for Policy A
# High Renewable: True
# Low Emission: True
# Germany does not qualify for Policy A
# High Renewable: False
# Low Emission: False
# India qualifies for Policy A
# High Renewable: False
# Low Emission: True
# Australia does not qualify for Policy A
# High Renewable: False
# Low Emission: False
# Brazil qualifies for Policy A
# High Renewable: True
# Low Emission: False
# Nigeria qualifies for Policy A
# High Renewable: False
# Low Emission: True
# Sweden qualifies for Policy A
# High Renewable: True
# Low Emission: False
# Bangladesh qualifies for Policy A
# High Renewable: False
# Low Emission: True
# USA does not qualify for Policy A
# High Renewable: False
# Low Emission: False

# %%
# Change the logic to allow countries with high renewable OR low emissions to qualify.

import pandas as pd


df= pd.read_csv("week3_policy_data.csv")

# Country data (you can modify these values below)
for index, row in df.iterrows():
    if not row['Region'] != 'Oceania':
        continue  # Skip countries in Oceania
    country_name = row['Country'] # Get the first country name
    percent_renewable = row['%Renewable']  # Get the first percent_renewable value
    co2_emissions = row['CO2_per_capita']  # Get the first CO2_per_capita value
    region = row['Region']  # Get the first region value


# Define logical conditions
    is_high_renewable = percent_renewable > 50
    is_low_emission = co2_emissions < 2
   

# Combined logical proposition using AND
    if is_high_renewable or is_low_emission:
        print(f"{country_name} qualifies for Policy A")
    else:
        print(f"{country_name} does not qualify for Policy A")

    # Display Boolean values for learning
    print("High Renewable:", is_high_renewable)
    print("Low Emission:", is_low_emission)
# Out:
# Nepal qualifies for Policy A
# High Renewable: True
# Low Emission: True
# Kenya qualifies for Policy A
# High Renewable: True
# Low Emission: True
# Germany does not qualify for Policy A
# High Renewable: False
# Low Emission: False
# India qualifies for Policy A
# High Renewable: False
# Low Emission: True
# Brazil qualifies for Policy A
# High Renewable: True
# Low Emission: False
# Nigeria qualifies for Policy A
# High Renewable: False
# Low Emission: True
# Sweden qualifies for Policy A
# High Renewable: True
# Low Emission: False
# Bangladesh qualifies for Policy A
# High Renewable: False
# Low Emission: True
# USA does not qualify for Policy A
# High Renewable: False
# Low Emission: False
