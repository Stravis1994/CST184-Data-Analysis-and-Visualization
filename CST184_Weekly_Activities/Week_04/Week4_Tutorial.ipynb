# %%
import pandas as pd

df = pd.read_csv("week4_energy_emissions.csv")
df.head()
# Out:
#   Region Energy_Type  CO2_Emissions
# 0   Asia       Solar           0.79
# 1   Asia       Solar           2.46
# 2   Asia       Solar           2.77
# 3   Asia       Solar           3.21
# 4   Asia       Solar           3.51

# %%
import math
from itertools import product

regions = df["Region"].unique()
types = df["Energy_Type"].unique()

# How many unique combinations?
print("Combinations (nCr):", math.comb(len(regions) + len(types), 2))

# How many region-energy pairs?
pairs = list(product(regions, types))
print("Region × Energy combinations:", len(pairs))
# Out:
# Combinations (nCr): 15
# Region × Energy combinations: 9

# %%
import math
from itertools import product
import csv

regions = ['Asia', 'Africa', 'Europe', 'South America']
types = df["Energy_Type"].unique()

# How many unique combinations?
print("Combinations (nCr):", math.comb(len(regions) + len(types), 2))

# How many region-energy pairs?
pairs = list(product(regions, types))
print("Region × Energy combinations:", len(pairs))
# Out:
# Combinations (nCr): 21
# Region × Energy combinations: 12

# %%
df["Region_Energy"] = df["Region"] + "_" + df["Energy_Type"]
df.head()
# Out:
#   Region Energy_Type  CO2_Emissions Region_Energy
# 0   Asia       Solar           0.79    Asia_Solar
# 1   Asia       Solar           2.46    Asia_Solar
# 2   Asia       Solar           2.77    Asia_Solar
# 3   Asia       Solar           3.21    Asia_Solar
# 4   Asia       Solar           3.51    Asia_Solar

# %%
df["Energy_Region"] = df["Energy_Type"] + "_" + df["Region"]
df.head()
# Out:
#   Region Energy_Type  CO2_Emissions Region_Energy Energy_Region
# 0   Asia       Solar           0.79    Asia_Solar    Solar_Asia
# 1   Asia       Solar           2.46    Asia_Solar    Solar_Asia
# 2   Asia       Solar           2.77    Asia_Solar    Solar_Asia
# 3   Asia       Solar           3.21    Asia_Solar    Solar_Asia
# 4   Asia       Solar           3.51    Asia_Solar    Solar_Asia

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x="Region_Energy", y="CO2_Emissions")
plt.title("CO₂ Emissions by Region + Energy Type")
plt.xticks(rotation=45)
plt.ylabel("CO₂ Emissions (tonnes)")
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df.loc[df["Energy_Type"] == "Hydro", "CO2_Emissions"] *= 1.2

plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x="Region_Energy", y="CO2_Emissions")
plt.title("CO₂ Emissions by Region + Energy Type")
plt.xticks(rotation=45)
plt.ylabel("CO₂ Emissions (tonnes)")
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df.loc[len(df)] = ["Asia", "Biomass", 4.2, "Asia_Biomass"]

plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x="Region_Energy", y="CO2_Emissions")
plt.title("CO₂ Emissions by Region + Energy Type")
plt.xticks(rotation=45)
plt.ylabel("CO₂ Emissions (tonnes)")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 4
#       1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
# ----> 4 df.loc[len(df)] = ["Asia", "Biomass", 4.2, "Asia_Biomass"]
#       6 plt.figure(figsize=(12, 6))
#       7 sns.boxplot(data=df, x="Region_Energy", y="CO2_Emissions")
#
# File c:\Users\seant\miniconda3\Lib\site-packages\pandas\core\indexing.py:938, in _LocationIndexer.__setitem__(self, key, value)
#     933 self._has_valid_setitem_indexer(key)
#     935 iloc: _iLocIndexer = (
#     936     cast("_iLocIndexer", self) if self.name == "iloc" else self.obj.iloc
#     937 )
# --> 938 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File c:\Users\seant\miniconda3\Lib\site-packages\pandas\core\indexing.py:1943, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1940     indexer, missing = convert_missing_indexer(indexer)
#    1942     if missing:
# -> 1943         self._setitem_with_indexer_missing(indexer, value)
#    1944         return
#    1946 if name == "loc":
#    1947     # must come after setting of missing
#
# File c:\Users\seant\miniconda3\Lib\site-packages\pandas\core\indexing.py:2298, in _iLocIndexer._setitem_with_indexer_missing(self, indexer, value)
#    2295     if is_list_like_indexer(value):
#    2296         # must have conforming columns
#    2297         if len(value) != len(self.obj.columns):
# -> 2298             raise ValueError("cannot set a row with mismatched columns")
#    2300     value = Series(value, index=self.obj.columns, name=indexer)
#    2302 if not len(self.obj):
#    2303     # We will ignore the existing dtypes instead of using
#    2304     #  internals.concat logic
#
# ValueError: cannot set a row with mismatched columns
